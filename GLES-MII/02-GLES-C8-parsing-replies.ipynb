# %% [markdown]
# # Parsing replies from Component 8
#
# This notebook constists mostly in code adapted from Short_version_C8_Longterm_Tracking_online.ipynb,
#
# and produces a csv file containing wave code, time window, answer key, raw text, lfdn and human labels for all responses in every wave.

# %%
import pandas as pd
from pandas.io.stata import StataReader as sr
import re
import matplotlib.pyplot as plt
from datetime import datetime as dt
from glob import glob
import seaborn as sns
import numpy as np

import seaborn as sns
sns.set_context('poster')

# %% [markdown]
# # Load data

# %%
# Set this to your local VW gdrive folder

local_folder='.'

# %%
# Load all datasets/waves as pandas dataframes and  pandas StataReader objects
filenames = glob(local_folder+'/Komponente 8/*.dta')
dataframes = [pd.read_stata(i, convert_categoricals=False) for i in filenames]
labels = [pd.read_stata(i, iterator=True) for i in filenames]

# %%
# Print examples of responses for a given wave 'idx'

idx = 17
df = dataframes[idx]
row = df.loc[0]
for k in row.keys():
    print(k.ljust(30)+str(row[k]))
# Out:
# study                         5340
# version                       4.0.0 (2013-06-27)
# year                          2009
# field                         2009-09-29 bis 2009-10-08
# ex_field                      2009-10-08 bis 2009-10-25
# glescomp                      10
# survey                        7
# lfdn                          36
# datetime                      2009-09-29 12:32:53
# lastaccs                      2009-09-29 12:48:21
# dauer                         928
# status                        2
# mut_sex                       0
# mut_age                       0
# mut_educ                      0
# mutation                      0
# gew1_t7_v0                    0.449
# gew2_t7_v0                    0.237
# gew1_t7_v1                    nan
# gew2_t7_v1                    nan
# gew1_t7_v2                    nan
# gew2_t7_v2                    nan
# v_01                          1
# v_02                          1
# v_03                          6
# T7_01                         10
# a01                           2
# a02                           2
# T7_02                         1
# T7_02a                        0
# T7_03                         1
# T7_05_c1                      100
# T7_05_c2                      100
# T7_05_c3                      100
# T7_05                         100
# T7_07a                        1000
# T7_07ac                       1000
# T7_07b                        1000
# T7_07bc                       1000
# T7_08                         1
# T7_13                         100
# T7_04a                        5
# T7_04ac                       5
# T7_04b                        5
# T7_04bc                       5
# T7_06_c1                      216
# T7_06_c2                      1001
# T7_06_c3                      1001
# T7_06                         Damit Die Spd nicht in die Regirung kommt
# T7_09                         801
# T7_09c                        206.0
# T7_10                         1
# T7_11a                        0
# T7_11b                        0
# T7_11c                        0
# T7_11d                        1
# T7_11e                        0
# T7_11f                        0
# T7_11s_c1                     1001
# T7_11s_c2                     1001
# T7_11s_c3                     1001
# T7_12                         5
# T7_14                         3
# T7_15a                        4
# T7_15b                        4
# T7_15c                        1
# T7_15d                        4
# T7_15e                        1
# T7_15f                        2
# T7_17                         1
# T7_18a                        1000
# T7_18ac                       1000
# T7_18b                        1000
# T7_18bc                       1000
# a03_c1                        3810
# a03_c2                        10000
# a03_c3                        10000
# a03_c4                        10000
# a03                           Arbeitslosigkeit
# a04                           5
# a04c                          5
# a05_c1                        3750
# a05_c2                        10001
# a05_c3                        10001
# a05_c4                        10001
# a05                           Ausländerproblem
# a06                           801
# a06c                          206
# a12a                          1
# a12b                          1
# a12c                          1
# a12d                          5
# a12e                          1
# a12f                          5
# a27a                          7
# a27b                          1
# a27c                          1
# a27d                          5
# a27e                          1
# a27f                          5
# a27g                          7
# a27h                          1
# a27i                          1
# a27j                          1
# a29                           1
# a13                           6
# a14a                          5
# a14b                          5
# a14c                          5
# a15a                          5
# a15b                          5
# a15c                          5
# a32a                          7
# a32b                          7
# a32c                          5
# a32d                          6
# a32e                          6
# a32f                          1
# a33                           9
# T7_19a                        6
# T7_19b                        6
# T7_20a                        98
# T7_20b                        98
# T7_20c                        98
# T7_20d                        98
# T7_20e                        98
# T7_20f                        3
# T7_20g                        3
# T7_20h                        3
# T7_20i                        3
# T7_20j                        3
# T7_20k                        3
# T7_20l                        3
# T7_21a                        5
# T7_21b                        5
# T7_21c                        3
# T7_21d                        3
# T7_21e                        3
# T7_21f                        4
# T7_21g                        3
# T7_21h                        3
# T7_21i                        3
# T7_22                         2
# T7_23a                        3
# T7_23b                        3
# T7_23c                        2
# T7_23d                        4
# T7_23e                        3
# T7_23f                        3
# T7_23g                        3
# T7_23h                        3
# a21                           3
# a19                           3
# a20                           3
# a22                           3
# a48                           3
# a16a                          1
# a16b                          6
# a16c                          1
# a16d                          1
# a16e                          1
# a16f                          -1
# a16g                          1
# a16h                          -1
# a17a                          1
# a17b                          3
# a17c                          3
# a17d                          1
# a17e                          1
# a17f                          1
# T7_24                         3
# T7_25a                        3
# T7_25b                        4
# T7_25c                        4
# T7_25d                        3
# T7_25e                        3
# T7_25f                        2
# T7_25g                        3
# T7_26a                        1
# T7_26b                        1
# T7_27                         3
# T7_28                         100
# T7_29                         98
# T7_29a                        98
# a11a                          996
# a11ac                         996
# a11b                          996
# a11bc                         996
# a25                           3
# a23                           3
# a24                           3
# T7_30a                        3
# T7_30b                        3
# a26                           3
# T7_31                         3
# T7_32a                        2
# T7_32b                        2
# T7_32c                        2
# T7_32d                        2
# T7_32e                        2
# T7_33                         2
# T7_34                         4
# T7_35                         4
# T7_36a                        3
# T7_36b                        2
# T7_36c                        2
# T7_36d                        2
# T7_36e                        3
# T7_36f                        2
# T7_36g                        2
# T7_36h                        3
# T7_36i                        2
# T7_36j                        2
# T7_37                         3
# T7_38                         2
# T7_39                         2
# T7_40                         3
# T7_44                         2
# T7_45                         2
# T7_46                         3
# T7_47                         3
# T7_48a                        100
# T7_48b                        100
# T7_48c                        100
# T7_48d                        100
# T7_48e                        100
# T7_48f                        100
# T7_48g                        100
# T7_48h                        100
# T7_48i                        100
# T7_48j                        2
# T7_48k                        100
# T7_48l                        100
# T7_48m                        100
# T7_48n                        100
# T7_48o                        100
# T7_48p                        100
# T7_49a                        1000
# T7_49ac                       1000
# T7_49b                        1000
# T7_49bc                       1000
# T7_49c                        1000
# T7_49cc                       1000
# T7_49d                        1000
# T7_49dc                       1000
# T7_49e                        1000
# T7_49f                        1000
# T7_49g                        1000
# T7_49gc                       1000
# T7_49h                        1000
# T7_49i                        1000
# T7_49ic                       1000
# T7_49j                        1000
# T7_49jc                       1000
# T7_49k                        1000
# T7_49l                        1000
# T7_49m                        1000
# T7_49mc                       1000
# T7_49n                        1000
# T7_49o                        1000
# T7_49oc                       1000
# T7_49p                        1000
# a31                           1
# T7_50a                        1
# T7_50b                        1
# T7_50c                        1
# T7_50d                        1
# T7_50e                        1
# T7_50f                        1
# T7_50g                        1
# T7_50h                        7
# T7_50aa_1                     100
# T7_50bb_1                     100
# T7_50cc_1                     100
# T7_50dd_1                     100
# T7_50ee_1                     100
# T7_50ff_1                     100
# T7_50gg_1                     100
# T7_50aa_2                     100
# T7_50bb_2                     100
# T7_50cc_2                     100
# T7_50dd_2                     100
# T7_50ee_2                     100
# T7_50ff_2                     100
# T7_50gg_2                     100
# T7_50aa_3                     100
# T7_50bb_3                     100
# T7_50cc_3                     100
# T7_50dd_3                     100
# T7_50ee_3                     100
# T7_50ff_3                     100
# T7_50gg_3                     100
# T7_50aa_4                     100
# T7_50bb_4                     100
# T7_50cc_4                     100
# T7_50dd_4                     100
# T7_50ee_4                     100
# T7_50ff_4                     100
# T7_50gg_4                     100
# T7_50aa_5                     100
# T7_50bb_5                     100
# T7_50dd_5                     100
# T7_50cc_5                     100
# T7_50ee_5                     100
# T7_50ff_5                     100
# T7_50gg_5                     100
# T7_50aa_6                     100
# T7_50bb_6                     100
# T7_50cc_6                     100
# T7_50dd_6                     100
# T7_50ee_6                     100
# T7_50ff_6                     100
# T7_50gg_6                     100
# T7_51a                        1
# T7_51b                        1
# T7_51c                        3
# T7_51d                        3
# T7_51e                        3
# T7_51aa_1                     100
# T7_51bb_1                     100
# T7_51cc_1                     100
# T7_51dd_1                     100
# T7_51ee_1                     100
# T7_51ff_1                     100
# T7_51gg_1                     100
# T7_51aa_2                     100
# T7_51bb_2                     100
# T7_51cc_2                     100
# T7_51dd_2                     100
# T7_51ee_2                     100
# T7_51ff_2                     100
# T7_51gg_2                     100
# T7_51aa_3                     0
# T7_51bb_3                     0
# T7_51cc_3                     0
# T7_51dd_3                     0
# T7_51ee_3                     0
# T7_51ff_3                     0
# T7_51gg_3                     1
# T7_51aa_4                     0
# T7_51bb_4                     0
# T7_51cc_4                     0
# T7_51dd_4                     0
# T7_51ee_4                     0
# T7_51ff_4                     0
# T7_51gg_4                     1
# T7_51aa_5                     0
# T7_51bb_5                     0
# T7_51dd_5                     0
# T7_51cc_5                     0
# T7_51ee_5                     0
# T7_51ff_5                     0
# T7_51gg_5                     1
# a34                           5
# T7_52                         7
# T7_52a                        0
# T7_52b                        0
# T7_52c                        0
# T7_52d                        0
# T7_52e                        0
# T7_52f                        0
# T7_52g                        1
# T7_52h                        0
# T7_52i                        0
# T7_52j                        1
# T7_52k                        0
# T7_52l                        0
# T7_52m                        0
# T7_52n                        0
# T7_52o                        0
# T7_53                         3
# T7_55a                        3
# T7_55b                        3
# T7_55c                        3
# T7_55d                        3
# T7_55e                        3
# T7_55f                        1
# T7_55g                        3
# T7_55h                        3
# T7_55i                        3
# T7_55j                        3
# T7_55k                        3
# T7_54                         100
# T7_56a                        100
# T7_56b                        100
# T7_56c                        100
# T7_56d                        100
# T7_56e                        100
# T7_56f                        100
# T7_56g                        100
# T7_57                         2
# T7_58a                        100
# T7_58b                        100
# T7_58c                        100
# T7_58d                        100
# T7_58e                        100
# T7_58f                        100
# T7_58g                        100
# T7_58h                        100
# T7_58i                        100
# T7_58j                        100
# T7_58k                        100
# T7_59a1                       100
# T7_59a2                       100
# T7_59a3                       100
# T7_59a4                       100
# T7_59a5                       100
# T7_59a6                       100
# T7_59b1                       100
# T7_59b2                       100
# T7_59b3                       100
# T7_59b4                       100
# T7_59b5                       100
# T7_59b6                       100
# T7_59c1                       100
# T7_59c2                       100
# T7_59c3                       100
# T7_59c4                       100
# T7_59c5                       100
# T7_59c6                       100
# T7_59d1                       100
# T7_59d2                       100
# T7_59d3                       100
# T7_59d4                       100
# T7_59d5                       100
# T7_59d6                       100
# T7_59e1                       100
# T7_59e2                       100
# T7_59e3                       100
# T7_59e4                       100
# T7_59e5                       100
# T7_59e6                       100
# T7_59f1                       100
# T7_59f2                       100
# T7_59f3                       100
# T7_59f4                       100
# T7_59f5                       100
# T7_59f6                       100
# T7_59g1                       100
# T7_59g2                       100
# T7_59g3                       100
# T7_59g4                       100
# T7_59g5                       100
# T7_59g6                       100
# T7_59h1                       100
# T7_59h2                       100
# T7_59h3                       100
# T7_59h4                       100
# T7_59h5                       100
# T7_59h6                       100
# T7_59i1                       100
# T7_59i2                       100
# T7_59i3                       100
# T7_59i4                       100
# T7_59i5                       100
# T7_59i6                       100
# T7_59j1                       100
# T7_59j2                       100
# T7_59j3                       100
# T7_59j4                       100
# T7_59j5                       100
# T7_59j6                       100
# T7_59k1                       100
# T7_59k2                       100
# T7_59k3                       100
# T7_59k4                       100
# T7_59k5                       100
# T7_59k6                       100
# a30                           2
# a30a                          5
# a30b                          1
# a30c                          100
# a30d                          100
# a30e                          1000
# a30ec                         1000
# T7_60                         1
# T7_61                         3
# T7_62a                        3
# T7_62b                        2
# T7_63                         1
# T7_63a                        1
# T7_64                         4
# T7_64a                        1
# T7_65a                        1
# T7_65aa                       1
# T7_65b                        0
# T7_65ba                       1
# T7_65c                        1
# T7_65ca                       0
# T7_65d                        0
# T7_65da                       1
# T7_65e                        0
# T7_65ea                       1
# T7_65f                        0
# T7_65fa                       1
# a39a                          0
# a39b                          0
# a39c                          0
# a39d                          0
# a39e                          0
# a39f                          1
# a39g                          0
# a39h                          0
# a39i                          0
# a39j                          0
# a39k                          0
# a39l                          0
# a54                           5
# a55                           1
# a50                           4
# a53                           100
# a41                           100
# T7_66                         100
# a53a                          100
# a52                           1
# a40                           100
# a40a                          100
# a42                           2
# a42a                          2
# a42b                          100
# a42c                          100
# a43                           1
# a43a                          100
# a43ac                         100
# a45                           1
# a45c                          0.0
# a46a                          2
# a46ac                         6
# a46b                          2
# a46bc                         6
# a44                           3
# a47                           6
# a51                           1991
# a36                           808
# a36c                          808
# a37                           100
# a38                           100
# T7_67a                        5
# T7_67b                        4
# T7_67c                        3
# T7_67d                        5
# T7_67e                        3
# T7_67f                        3
# T7_67g                        3
# T7_67h                        5
# elecdist                      118
# elecdist1                     nan
# elecdist2                     nan
# elecdist3                     nan
# elecdist4                     nan
# elecdist5                     nan
# elecdist6                     nan
# elecdist7                     nan
# elecdist8                     nan
# elecdist9                     nan
# elecdist10                    nan
# elecdist11                    nan
# elecdist12                    nan
# T_Start                       3
# T_Quoten                      10
# T_T7_01                       4
# T_A01                         4
# T_A02                         6
# T_T7_02                       9
# T_T7_03                       5
# T_T7_05                       0
# T_T7_07                       0
# T_T7_13                       0
# T_T7_04                       9
# T_T7_06                       22
# T_T7_08a                      0
# T_T7_08b                      0
# T_T7_08c                      8
# T_T7_08d                      0
# T_T7_08e                      0
# T_T7_08f                      0
# T_T7_09                       7
# T_T7_10                       6
# T_T7_11                       3
# T_T7_12                       27
# T_T7_14                       3
# T_T7_15                       14
# T_T7_17                       7
# T_T7_18                       0
# T_A03                         9
# T_A04                         16
# T_A05                         8
# T_A06                         5
# T_A12                         11
# T_A27                         29
# T_A29                         5
# T_A13                         9
# T_A14                         8
# T_A15                         10
# T_A32                         19
# T_A33                         11
# T_T7_19                       3
# T_T7_20a                      11
# T_T7_20b                      4
# T_T7_20c                      18
# T_T7_21                       34
# T_T7_22                       6
# T_T7_23                       20
# T_A21                         5
# T_A19                         7
# T_A20                         8
# T_A22                         3
# T_A48                         2
# T_A16                         24
# T_A17                         36
# T_T7_24                       4
# T_T7_25                       20
# T_T7_26a                      7
# T_T7_26b                      12
# T_T7_27                       2
# T_T7_28                       0
# T_T7_29                       3
# T_A11                         5
# T_A25                         4
# T_A23                         3
# T_A24                         5
# T_T7_30a                      3
# T_T7_30b                      2
# T_A26                         3
# T_T7_31                       3
# T_T7_32                       7
# T_T7_33                       9
# T_T7_34                       4
# T_T7_35                       2
# T_T7_36a                      10
# T_T7_36b                      8
# T_T7_37                       27
# T_T7_38                       6
# T_T7_39                       12
# T_T7_40                       2
# T_T7_44                       15
# T_T7_45                       5
# T_T7_46                       4
# T_T7_47                       3
# T_T7_48                       5
# T_T7_49a                      0
# T_T7_49b                      0
# T_T7_49c                      0
# T_T7_49d                      0
# T_T7_49e                      0
# T_A31                         9
# T_T7_50                       18
# T_T7_50aa                     0
# T_T7_51                       11
# T_T7_51aa                     8
# T_A34                         6
# T_T7_52a                      11
# T_T7_52b                      8
# T_T7_53                       4
# T_T7_55a                      10
# T_T7_55b                      9
# T_T7_54                       0
# T_T7_56                       0
# T_T7_57                       6
# T_T7_58                       0
# T_T7_59                       0
# T_A30                         4
# T_A30a                        3
# T_A30b                        3
# T_A30c                        0
# T_A30d                        0
# T_A30e                        0
# T_T7_60                       4
# T_T7_61                       3
# T_T7_62                       9
# T_T7_63                       5
# T_T7_64                       16
# T_T7_65                       6
# T_A39                         12
# T_A54                         7
# T_A55                         3
# T_A50                         9
# T_A53                         0
# T_A41                         0
# T_T7_66                       0
# T_A53a                        0
# T_A52                         3
# T_A40                         0
# T_A40a                        0
# T_A42                         4
# T_A42a                        4
# T_A42b                        0
# T_A42c                        0
# T_A43                         4
# T_A43a                        0
# T_A45                         9
# T_A46                         5
# T_A44                         5
# T_A47                         6
# T_A51                         6
# T_A36                         4
# T_A37                         0
# T_A38                         0
# T_T7_67a                      16
# T_T7_67b                      15
# T1_Start                      3
# T2_Quoten                     13
# T3_T7_01                      17
# T4_A01                        21
# T5_A02                        27
# T6_T7_02                      36
# T7_T7_03                      41
# T8_T7_05                      0
# T9_T7_07                      0
# T10_T7_13                     0
# T11_T7_04                     50
# T12_T7_06                     72
# T13_T7_08a                    0
# T14_T7_08b                    0
# T15_T7_08c                    80
# T16_T7_08d                    0
# T17_T7_08e                    0
# T18_T7_08f                    0
# T19_T7_09                     87
# T20_T7_10                     93
# T21_T7_11                     96
# T22_T7_12                     123
# T23_T7_14                     126
# T24_T7_15                     140
# T26_T7_17                     147
# T27_T7_18                     0
# T28_A03                       156
# T29_A04                       172
# T30_A05                       180
# T31_A06                       185
# T32_A12                       196
# T33_A27                       225
# T34_A29                       230
# T35_A13                       239
# T36_A14                       247
# T37_A15                       257
# T38_A32                       276
# T39_A33                       287
# T40_T7_19                     290
# T41_T7_20a                    301
# T42_T7_20b                    305
# T43_T7_20c                    323
# T44_T7_21                     357
# T45_T7_22                     363
# T46_T7_23                     383
# T47_A21                       388
# T48_A19                       395
# T49_A20                       403
# T50_A22                       406
# T51_A48                       408
# T52_A16                       432
# T53_A17                       468
# T54_T7_24                     472
# T55_T7_25                     492
# T56_T7_26a                    499
# T57_T7_26b                    511
# T58_T7_27                     513
# T59_T7_28                     0
# T60_T7_29                     516
# T61_A11                       521
# T62_A25                       525
# T63_A23                       528
# T64_A24                       533
# T65_T7_30a                    536
# T66_T7_30b                    538
# T67_A26                       541
# T68_T7_31                     544
# T69_T7_32                     551
# T70_T7_33                     560
# T71_T7_34                     564
# T72_T7_35                     566
# T73_T7_36a                    576
# T74_T7_36b                    584
# T75_T7_37                     611
# T76_T7_38                     617
# T77_T7_39                     629
# T78_T7_40                     631
# T79_T7_44                     646
# T80_T7_45                     651
# T81_T7_46                     655
# T82_T7_47                     658
# T83_T7_48                     663
# T84_T7_49a                    0
# T85_T7_49b                    0
# T86_T7_49c                    0
# T87_T7_49d                    0
# T88_T7_49e                    0
# T89_A31                       672
# T90_T7_50                     690
# T91_T7_50aa                   0
# T92_T7_51                     701
# T93_T7_51aa                   709
# T94_A34                       715
# T95_T7_52a                    726
# T96_T7_52b                    734
# T97_T7_53                     738
# T98_T7_55a                    748
# T99_T7_55b                    757
# T100_T7_54                    0
# T101_T7_56                    0
# T102_T7_57                    763
# T103_T7_58                    0
# T104_T7_59                    0
# T105_A30                      767
# T106_A30a                     770
# T107_A30b                     773
# T108_A30c                     0
# T109_A30d                     0
# T110_A30e                     0
# T111_T7_60                    777
# T112_T7_61                    780
# T113_T7_62                    789
# T114_T7_63                    794
# T115_T7_64                    810
# T116_T7_65                    816
# T117_A39                      828
# T118_A54                      835
# T119_A55                      838
# T120_A50                      847
# T121_A53                      0
# T122_A41                      0
# T123_T7_66                    0
# T124_A53a                     0
# T125_A52                      850
# T126_A40                      0
# T127_A40a                     0
# T128_A42                      854
# T129_A42a                     858
# T130_A42b                     0
# T131_A42c                     0
# T132_A43                      862
# T133_A43a                     0
# T134_A45                      871
# T135_A46                      876
# T136_A44                      881
# T137_A47                      887
# T138_A51                      893
# T139_A36                      897
# T140_A37                      0
# T141_A38                      0
# T142_T7_67a                   913
# T143_T7_67b                   928
# T144_Experiment               0
# ProbFlag                      0
# ProbKomm
# V001                          5
# V002                          1
# T7_06_info                    0
# a03_info                      0
# a05_info                      0
# teilexp                       1
# ex_lastaccs                   2009-10-08 19:35:06
# ex_datetime                   2009-10-08 19:28:06
# ex_dauer                      420.0
# ex_status                     1.0
# gew1_t7exp_v0                 0.429
# gew2_t7exp_v0                 0.227
# gew1_t7exp_v1                 0.432
# gew2_t7exp_v1                 0.227
# gew1_t7exp_v2                 0.413
# gew2_t7exp_v2                 0.206
# Split                         1.0
# v1                            1.0
# v2                            1991.0
# v3                            6.0
# ex_29                         1.0
# ex_20                         6.0
# ex_21_1                       101.0
# ex_21_2                       101.0
# ex_21_3                       101.0
# ex_21_4                       101.0
# ex_21_5                       101.0
# ex_02a                        3.0
# ex_02b                        3.0
# ex_02c                        3.0
# ex_03a                        4.0
# ex_03b                        3.0
# ex_03c                        4.0
# ex_03d                        3.0
# ex_03e                        3.0
# ex_04a                        3.0
# ex_04b                        2.0
# ex_04c                        2.0
# ex_04d                        2.0
# ex_04e                        2.0
# ex_04f                        2.0
# ex_04g                        2.0
# ex_04h                        4.0
# ex_04i                        4.0
# ex_04j                        3.0
# ex_04k                        3.0
# ex_04l                        3.0
# ex_04m                        3.0
# ex_04n                        2.0
# ex_04o                        3.0
# ex_13_c1                      2.0
# ex_13_c2                      1.0
# ex_13_c3                      100.0
# ex_06                         3.0
# ex_07                         4.0
# ex_07c                        4.0
# ex_08                         3.0
# ex_09_c1                      100.0
# ex_09_c2                      100.0
# ex_10a                        0.0
# ex_10b                        0.0
# ex_10c                        0.0
# ex_10d                        0.0
# ex_10e                        1.0
# ex_10f                        1.0
# ex_10g                        0.0
# ex_10h                        0.0
# ex_10i                        0.0
# ex_10j                        0.0
# ex_10k                        0.0
# ex_10l                        0.0
# ex_10m                        0.0
# ex_10n                        0.0
# ex_10o                        0.0
# ex_10s_c1                     100.0
# ex_10s_c2                     100.0
# ex_11                         6.0
# ex_12a                        2.0
# ex_12b                        1.0
# ex_12c                        1.0
# ex_12d                        1.0
# ex_12e                        1.0
# ex_12f                        2.0
# ex_12g                        1.0
# ex_12h                        1.0
# ex_12i                        2.0
# ex_12j                        1.0
# ex_12k                        1.0
# ex_12l                        1.0
# ex_12m                        1.0
# ex_12n                        1.0
# ex_12o                        1.0
# ex_14a                        3.0
# ex_14b                        3.0
# ex_14c                        3.0
# ex_14d                        3.0
# ex_15a                        3.0
# ex_15b                        3.0
# ex_15c                        3.0
# ex_15d                        3.0
# ex_15e                        3.0
# ex_15f                        3.0
# ex_15g                        3.0
# ex_15h                        3.0
# ex_15i                        3.0
# ex_15j                        3.0
# ex_15k                        2.0
# ex_15o                        2.0
# ex_16a                        4.0
# ex_16b                        3.0
# ex_16c                        4.0
# ex_16d                        3.0
# ex_16e                        3.0
# ex_17                         3.0
# ex_30                         3.0
# ex_18                         3.0
# ex_19a                        3.0
# ex_19b                        3.0
# ex_19c                        3.0
# ex_19d                        3.0
# ex_19e                        3.0
# ex_19f                        3.0
# ex_19g                        3.0
# ex_01a                        5.0
# ex_01b                        3.0
# ex_01c                        3.0
# ex_01d                        3.0
# ex_01e                        3.0
# ex_01f                        3.0
# ex_01g                        3.0
# ex_01h                        3.0
# ex_22                         100.0
# ex_23                         100.0
# ex_23s                        100.0
# ex_24                         100.0
# ex_24j                        100.0
# ex_24m                        100.0
# ex_25                         100.0
# ex_25j                        100.0
# ex_25s                        100.0
# ex_25m                        100.0
# ex_26a                        6.0
# ex_26b                        6.0
# ex_26c                        6.0
# ex_26d                        6.0
# ex_26e                        6.0
# ex_26f                        6.0
# ex_26g                        6.0
# ex_27                         2.0
# ex_27m                        100.0
# ex_28                         2.0
# ex_28m                        100.0
# t1_ex_Start                   4.0
# t2_ex_Quoten                  21.0
# t3_ex_29                      27.0
# t4_ex_20                      32.0
# t5_ex_21a                     0.0
# t6_ex_21b                     0.0
# t7_ex_02                      40.0
# t8_ex_03                      50.0
# t9_ex_04a                     104.0
# t10_ex_04b                    131.0
# t11_ex_13                     187.0
# t12_ex_00                     208.0
# t13_ex_001a                   215.0
# t14_ex_001b                   218.0
# t15_ex_002a                   0.0
# t16_ex_002b                   0.0
# t17_ex_003a                   0.0
# t18_ex_003b                   0.0
# t19_ex_004a                   0.0
# t20_ex_004b                   0.0
# t21_ex_005a                   0.0
# t22_ex_005b                   0.0
# t23_ex_006a                   0.0
# t24_ex_006b                   0.0
# t25_ex_007a                   0.0
# t26_ex_007b                   0.0
# t27_ex_008a                   0.0
# t28_ex_008b                   0.0
# t29_ex_06                     225.0
# t30_ex_07                     229.0
# t31_ex_08                     234.0
# t32_ex_09                     0.0
# t33_ex_10                     256.0
# t34_ex_11                     259.0
# t35_ex_12                     295.0
# t36_ex_14                     305.0
# t37_ex_15a                    313.0
# t38_ex_15b                    320.0
# t39_ex_16                     328.0
# t40_ex_17                     331.0
# t41_ex_30                     336.0
# t42_ex_18                     339.0
# t43_ex_19                     384.0
# t44_ex_01a                    391.0
# t45_ex_01b                    395.0
# t46_ex_22                     0.0
# t47_ex_23                     0.0
# t48_ex_24                     0.0
# t49_ex_25                     0.0
# t50_ex_26                     408.0
# t51_ex_27                     415.0
# t52_ex_28                     420.0
# t_ex_Start                    4.0
# t_ex_Quoten                   17.0
# t_ex_29                       6.0
# t_ex_20                       5.0
# t_ex_21a                      0.0
# t_ex_21b                      0.0
# t_ex_02                       8.0
# t_ex_03                       10.0
# t_ex_04a                      54.0
# t_ex_04b                      27.0
# t_ex_13                       56.0
# t_ex_00                       21.0
# t_ex_001a                     7.0
# t_ex_001b                     3.0
# t_ex_002a                     0.0
# t_ex_002b                     0.0
# t_ex_003a                     0.0
# t_ex_003b                     0.0
# t_ex_004a                     0.0
# t_ex_004b                     0.0
# t_ex_005a                     0.0
# t_ex_005b                     0.0
# t_ex_006a                     0.0
# t_ex_006b                     0.0
# t_ex_007a                     0.0
# t_ex_007b                     0.0
# t_ex_008a                     0.0
# t_ex_008b                     0.0
# t_ex_06                       7.0
# t_ex_07                       4.0
# t_ex_08                       5.0
# t_ex_09                       0.0
# t_ex_10                       22.0
# t_ex_11                       3.0
# t_ex_12                       36.0
# t_ex_14                       10.0
# t_ex_15a                      8.0
# t_ex_15b                      7.0
# t_ex_16                       8.0
# t_ex_17                       3.0
# t_ex_30                       5.0
# t_ex_18                       3.0
# t_ex_19                       45.0
# t_ex_01a                      7.0
# t_ex_01b                      4.0
# t_ex_22                       0.0
# t_ex_23                       0.0
# t_ex_24                       0.0
# t_ex_25                       0.0
# t_ex_26                       13.0
# t_ex_27                       7.0
# t_ex_28                       5.0

# %%
idx = 17
df = dataframes[idx]

keys = [ key for (key, val) in labels[idx].variable_labels().items() if 'Wichtigstes Problem' in val ]
df.filter(keys).head()
# Out:
#    T_A04  a03_c2   a04  T_A03                   a03  T29_A04  a04c  T28_A03  \
# 0     16   10000     5      9      Arbeitslosigkeit      172     5      156
# 1      0   10000  1000      2                    99        0  1000      156
# 2      8   10000   808     28   Die Arbeislosigkeit      396   809      388
# 3      2   10000     7     10  Wirtschaftliche Lage      121     7      119
# 4      0   10000  1000      3                    99        0  1000      278
#
#    a03_c3  a03_c1  a03_c4
# 0   10000    3810   10000
# 1   10000    9999   10000
# 2   10000    3810   10000
# 3   10000    3910   10000
# 4   10000    9999   10000

# %%
#get labels of variables concerning most important problem
vardict_vls = [pd.read_stata(i, iterator=True) for i in filenames]


for l in labels:
    print(dataframes[labels.index(l)].loc[0, 'study'])
    
    vardict = l.variable_labels()
    for key, val in vardict.items():
       
        if 'Wichtigstes Problem' in val:
            print(key, ': ', val)           
            
    print('\n')
# Out:
# 5732
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c6 :  Wichtigstes Problem (Codierung 6)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5336
# t_A03 :  Zeit_Seite_A03 Wichtigstes Problem
# a04 :  Wichtigstes Problem, Lösungskompetenz (Version A)
# a03_c :  Wichtigstes Problem (Codierung)
# a04c :  Wichtigstes Problem, Lösungskompetenz (Version B)
# t47_A03 :  Zeit_kumuliert_A03 Wichtigstes Problem
# t48_A04 :  Zeit_kumuliert_A04 Wichtigstes Problem, Lösungskompetenz
# t_A04 :  Zeit_Seite_A04 Wichtigstes Problem, Lösungskompetenz
#
#
# 5343
# T11_A03 :  Zeit_kumuliert_A03 _Wichtigstes Problem
# T_A04 :  Zeit_Seite_A04 _Wichtigstes Problem, Loesungskompetenz
# E27b :  Wichtigstes Problem, Problemloesung
# T_E27b :  Zeit_Seite_E27b _Wichtigstes Problem, Bund, Problemloesung
# A03_c4 :  Wichtigstes Problem: 4. Nennung
# A03s :  Wichtigstes Problem
# A03_c1 :  Wichtigstes Problem: 1. Nennung
# T12_A04 :  Zeit_kumuliert_A04 _Wichtigstes Problem, Loesungskompetenz
# T_A03 :  Zeit_Seite_A03 _Wichtigstes Problem
# T13_E27b :  Zeit_kumuliert_E27b _Wichtigstes Problem, Bund, Problemloesung
# A04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
# A03_c2 :  Wichtigstes Problem: 2. Nennung
# A03_c3 :  Wichtigstes Problem: 3. Nennung
# A04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
#
#
# 6815
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5350
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c1 :  Wichtigstes Problem: 1. Codierung
# t10c6 :  Wichtigstes Problem: 6. Codierung
# t10c4 :  Wichtigstes Problem: 4. Codierung
# t10c7 :  Wichtigstes Problem: 7. Codierung
# t10c2 :  Wichtigstes Problem: 2. Codierung
# t103 :  Wichtigstes Problem, Loesungsebene
# t10s :  Wichtigstes Problem
# t10c3 :  Wichtigstes Problem: 3. Codierung
# t10c5 :  Wichtigstes Problem: 5. Codierung
#
#
# 5721
# t10_c2 :  Wichtigstes Problem (2. Codierung)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10_c5 :  Wichtigstes Problem (5. Codierung)
# t10_c4 :  Wichtigstes Problem (4. Codierung)
# t10_c3 :  Wichtigstes Problem (3. Codierung)
# t10s :  Wichtigstes Problem
# t10_c1 :  Wichtigstes Problem (1. Codierung)
#
#
# 5729
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10s :  Wichtigstes Problem
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5727
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10s :  Wichtigstes Problem
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5335
# a03_c3 :  Wichtigstes Problem (3. Codierung)
# t42_A03 :  Zeit kumuliert_A03 Wichtigstes Problem
# e27a :  Wichtigstes Problem, Ebene der Problembehandlung
# t44_E27a :  Zeit kumuliert_E27a Wichtigstes Problem, Ebene der Problembehandlung
# e27b :  Wichtigstes Problem, Ebene der Problemloesung
# t45_E27b :  Zeit kumuliert_E27b Wichtigstes Problem, Ebene der Problemloesung
# a03_c2 :  Wichtigstes Problem (2. Codierung)
# a03_c1 :  Wichtigstes Problem (1. Codierung)
# a03_c4 :  Wichtigstes Problem (4. Codierung)
#
#
# 5345
# A03s :  Wichtigstes Problem
# T9_A03 :  Zeit kumuliert Wichtigstes Problem
# A03_c7 :  Wichtigstes Problem: 7. Codierung
# A03_c5 :  Wichtigstes Problem: 5. Codierung
# T_A03 :  Zeit Seite Wichtigstes Problem
# A03_c1 :  Wichtigstes Problem: 1. Codierung
# A03_c2 :  Wichtigstes Problem: 2. Codierung
# T_A04 :  Zeit Seite Wichtigstes Problem, Loesungskompetenz
# A03_c3 :  Wichtigstes Problem: 3. Codierung
# A04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
# A03_c6 :  Wichtigstes Problem: 6. Codierung
# T10_A04 :  Zeit kumuliert Wichtigstes Problem, Loesungskompetenz
# A03_c4 :  Wichtigstes Problem: 4. Codierung
# A03_c8 :  Wichtigstes Problem: 8. Codierung
# A04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
#
#
# 5734
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5731
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 6817
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5344
# A03s :  Wichtigstes Problem
# T_A04 :  Zeit_Seite_A04_Wichtigstes Problem, Loesungskompetenz
# T_A03 :  Zeit_Seite_A03_Wichtigstes Problem
# T10_A04 :  Zeit_kumuliert_A04_Wichtigstes Problem, Loesungskompetenz
# A03_c1 :  Wichtigstes Problem: 1. Codierung
# A04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
# T9_A03 :  Zeit_kumuliert_A03_Wichtigstes Problem
# A04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
#
#
# 5334
# t_A03 :  Zeit Seite_A03 Wichtigstes Problem
# t41_A03 :  Zeit kumuliert_A03 Wichtigstes Problem
# a03_c3 :  Wichtigstes Problem (3. Codierung)
# a03_c2 :  Wichtigstes Problem (2. Codierung)
# a03_c1 :  Wichtigstes Problem (1. Codierung)
# a03_c4 :  Wichtigstes Problem (4. Codierung)
#
#
# 5341
# T11_A03 :  Zeit_kumuliert_A03_Wichtigstes Problem
# A03_c4 :  Wichtigstes Problem: 4. Nennung
# A03_c5 :  Wichtigstes Problem: 5. Nennung
# A03s :  Wichtigstes Problem
# A03_c1 :  Wichtigstes Problem: 1. Nennung
# T12_A04 :  Zeit_kumuliert_A04_Wichtigstes Problem, Loesungskompetenz
# T_A03 :  Zeit_Seite_A03_Wichtigstes Problem
# A03_c2 :  Wichtigstes Problem: 2. Nennung
# T_A04 :  Zeit_Seite_A04_Wichtigstes Problem, Loesungskompetenz
# A03_c3 :  Wichtigstes Problem: 3. Nennung
# A04 :  Loesungskompetenz: Wichtigstes Problem (Version A)
# A04c :  Loesungskompetenz: Wichtigstes Problem (Version B)
#
#
# 5722
# t10_c2 :  Wichtigstes Problem (2. Codierung)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10_c5 :  Wichtigstes Problem (5. Codierung)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10_c3 :  Wichtigstes Problem (3. Codierung)
# t10s :  Wichtigstes Problem
# t10_c4 :  Wichtigstes Problem (4. Codierung)
# t10_c1 :  Wichtigstes Problem (1. Codierung)
#
#
# 5340
# T_A04 :  Zeit_Seite_A04_Loesungskompetenz: Wichtigstes Problem
# a03_c2 :  Wichtigstes Problem (2. Codierung)
# a04 :  Loesungskompetenz: Wichtigstes Problem (Version A)
# T_A03 :  Zeit_Seite_A03_Wichtigstes Problem
# a03 :  Wichtigstes Problem
# T29_A04 :  Zeit_kumuliert_A04_Loesungskompetenz: Wichtigstes Problem
# a04c :  Loesungskompetenz: Wichtigstes Problem (Version B)
# T28_A03 :  Zeit_kumuliert_A03_Wichtigstes Problem
# a03_c3 :  Wichtigstes Problem (3. Codierung)
# a03_c1 :  Wichtigstes Problem (1. Codierung)
# a03_c4 :  Wichtigstes Problem (4. Codierung)
#
#
# 6816
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10c3 :  Wichtigstes Problem (Codierung 3)
#
#
# 5730
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10s :  Wichtigstes Problem
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5719
# t10_c2 :  Wichtigstes Problem (2. Codierung)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10_c5 :  Wichtigstes Problem (5. Codierung)
# t10_c4 :  Wichtigstes Problem (4. Codierung)
# t10_c3 :  Wichtigstes Problem (3. Codierung)
# t10s :  Wichtigstes Problem
# t10_c1 :  Wichtigstes Problem (1. Codierung)
#
#
# 5349
# A03_c6 :  Wichtigstes Problem: 6. Codierung
# A03s :  Wichtigstes Problem
# A03_c11 :  Wichtigstes Problem: 11. Codierung
# A03_c8 :  Wichtigstes Problem: 8. Codierung
# A03_c12 :  Wichtigstes Problem: 12. Codierung
# A03_c10 :  Wichtigstes Problem: 10. Codierung
# T10_A04 :  Zeit kumuliert Wichtigstes Problem, Loesungskompetenz
# A03_c7 :  Wichtigstes Problem: 7. Codierung
# A03_c4 :  Wichtigstes Problem: 4. Codierung
# A03_c5 :  Wichtigstes Problem: 5. Codierung
# A03_c1 :  Wichtigstes Problem: 1. Codierung
# T_A03 :  Zeit Seite Wichtigstes Problem
# A04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
# A03_c2 :  Wichtigstes Problem: 2. Codierung
# A03_c9 :  Wichtigstes Problem: 9. Codierung
# T_A04 :  Zeit Seite Wichtigstes Problem, Loesungskompetenz
# A03_c3 :  Wichtigstes Problem: 3. Codierung
# T9_A03 :  Zeit kumuliert Wichtigstes Problem
# A04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
#
#
# 5723
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10s :  Wichtigstes Problem
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10c1 :  Wichtigstes Problem (Codierung 1)
#
#
# 5337
# t_A03 :  Zeit_Seite_A03 Wichtigstes Problem
# a04 :  Wichtigstes Problem, Lösungskompetenz (Version A)
# t78_A03 :  Zeit_kumuliert_A03 Wichtigstes Problem
# k13c :  Wichtigstes Problem, Lösungskompetenz Koalition (Version B)
# t80_K13 :  Zeit_kumuliert_K13 Wichtigstes Problem, Lösungskompetenz Koalition
# a03_c1 :  Wichtigstes Problem (1. Codierung)
# a04c :  Wichtigstes Problem, Lösungskompetenz (Version B)
# t_K13 :  Zeit_Seite_K13 Wichtigstes Problem, Lösungskompetenz Koalition
# t79_A04 :  Zeit_kumuliert_A04 Wichtigstes Problem, Lösungskompetenz
# k13 :  Wichtigstes Problem, Lösungskompetenz Koalition (Version A)
# a03_c3 :  Wichtigstes Problem (3. Codierung)
# a03_c2 :  Wichtigstes Problem (2. Codierung)
# t_A04 :  Zeit_Seite_A04 Wichtigstes Problem, Lösungskompetenz
# a03_c4 :  Wichtigstes Problem (4. Codierung)
#
#
# 5347
# T11_A03 :  Zeit kumuliert Wichtigstes Problem
# A03s :  Wichtigstes Problem
# A03_c11 :  Wichtigstes Problem: 11. Codierung
# T_A04 :  Zeit Seite Wichtigstes Problem, Loesungskompetenz
# A03_c7 :  Wichtigstes Problem: 7. Codierung
# A03_c5 :  Wichtigstes Problem: 5. Codierung
# T_A03 :  Zeit Seite Wichtigstes Problem
# A03_c2 :  Wichtigstes Problem: 2. Codierung
# E27b :  Wichtigstes Problem, Problemloesung
# A03_c3 :  Wichtigstes Problem: 3. Codierung
# A04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
# A03_c6 :  Wichtigstes Problem: 6. Codierung
# A03_c8 :  Wichtigstes Problem: 8. Codierung
# A03_c10 :  Wichtigstes Problem: 10. Codierung
# A03_c4 :  Wichtigstes Problem: 4. Codierung
# T_E27b :  Zeit Seite Wichtigstes Problem, Problemloesung
# A03_c1 :  Wichtigstes Problem: 1. Codierung
# T12_A04 :  Zeit kumuliert Wichtigstes Problem, Loesungskompetenz
# T13_E27b :  Zeit kumuliert Wichtigstes Problem, Problemloesung
# A04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
# A03_c9 :  Wichtigstes Problem: 9. Codierung
#
#
# 5351
# t10_c2 :  Wichtigstes Problem (2. Codierung)
# t11b :  Wichtigstes Problem, Lösungskompetenz (Version B)
# t10_c5 :  Wichtigstes Problem (5. Codierung)
# t10_c4 :  Wichtigstes Problem (4. Codierung)
# t11a :  Wichtigstes Problem, Lösungskompetenz (Version A)
# t10_c3 :  Wichtigstes Problem (3. Codierung)
# t10s :  Wichtigstes Problem
# t10_c1 :  Wichtigstes Problem (1. Codierung)
#
#
# 5720
# t10_c2 :  Wichtigstes Problem (2. Codierung)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10_c5 :  Wichtigstes Problem (5. Codierung)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10_c3 :  Wichtigstes Problem (3. Codierung)
# t10_c4 :  Wichtigstes Problem (4. Codierung)
# t10_c1 :  Wichtigstes Problem (1. Codierung)
#
#
# 5724
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10s :  Wichtigstes Problem
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c6 :  Wichtigstes Problem (Codierung 6)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5346.0
# T11_A03 :  Zeit kummuliert Wichtigstes Problem
# A03s :  Wichtigstes Problem
# A03_c7 :  Wichtigstes Problem: 7. Codierung
# A03_c5 :  Wichtigstes Problem: 5. Codierung
# T_A03 :  Zeit Seite Wichtigstes Problem
# A03_c2 :  Wichtigstes Problem: 2. Codierung
# T_A04 :  Zeit Seite Wichtigstes Problem, Loesungskompetenz
# A03_c3 :  Wichtigstes Problem: 3. Codierung
# A04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
# A03_c6 :  Wichtigstes Problem: 6. Codierung
# A03_c4 :  Wichtigstes Problem: 4. Codierung
# A03_c1 :  Wichtigstes Problem: 1. Codierung
# T12_A04 :  Zeit kummuliert Wichtigstes Problem, Loesungskompetenz
# A04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
# A03_c8 :  Wichtigstes Problem: 8. Codierung
#
#
# 5348
# a03_c1 :  Wichtigstes Problem: 1. Codierung
# a03_c5 :  Wichtigstes Problem: 5. Codierung
# a04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10_a04 :  Zeit kumuliert Wichtigstes Problem, Loesungskompetenz
# a03_c9 :  Wichtigstes Problem: 9. Codierung
# a03_c7 :  Wichtigstes Problem: 7. Codierung
# a03_c6 :  Wichtigstes Problem: 6. Codierung
# t_a03 :  Zeit Seite Wichtigstes Problem
# a03_c10 :  Wichtigstes Problem: 10. Codierung
# a03_c8 :  Wichtigstes Problem: 8. Codierung
# t_a04 :  Zeit Seite Wichtigstes Problem, Loesungskompetenz
# a04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t9_a03 :  Zeit kumuliert Wichtigstes Problem
# a03_c3 :  Wichtigstes Problem: 3. Codierung
# a03_c2 :  Wichtigstes Problem: 2. Codierung
# a03_c4 :  Wichtigstes Problem: 4. Codierung
# a03s :  Wichtigstes Problem
#
#
# 5728
# t10s :  Wichtigstes Problem
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5339
# T_A04 :  Zeit_Seite_A04 Wichtigstes Problem, Loesungskompetenz
# a03_c3 :  Wichtigstes Problem (3. Codierung)
# a04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
# a04s :  Wichtigstes Problem, Loesungskompetenz (Version C)
# T_A03 :  Zeit_Seite_A03 Wichtigstes Problem
# T52_A04 :  Zeit_kumuliert_A04 Wichtigstes Problem, Loesungskompetenz
# a03_c1 :  Wichtigstes Problem (1. Codierung)
# a03_c4 :  Wichtigstes Problem (4. Codierung)
# a04s_c :  Wichtigstes Problem, Loesungskompetenz (Version D)
# a04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
# T51_A03 :  Zeit_kumuliert_A03 Wichtigstes Problem
# a03_c2 :  Wichtigstes Problem (2. Codierung)
# a03s :  Wichtigstes Problem
#
#
# 5338
# t_A03 :  Zeit_Seite_A03 Wichtigstes Problem
# a04 :  Wichtigstes Problem, Lösungskompetenz (Version A)
# t_A04 :  Zeit_Seite_A04 Wichtigstes Problem, Lösungskompetenz
# t21_A03 :  Zeit_kumuliert_t21_A03 Wichtigstes Problem
# t22_A04 :  Zeit_kumuliert_t22_A04 Wichtigstes Problem, Lösungskompetenz
# a04c :  Wichtigstes Problem, Lösungskompetenz (Version B)
# a03_c3 :  Wichtigstes Problem (3. Codierung)
# a03_c2 :  Wichtigstes Problem (2. Codierung)
# a03_c1 :  Wichtigstes Problem (1. Codierung)
# a03_c4 :  Wichtigstes Problem (4. Codierung)
#
#
# 5342
# A03s :  Wichtigstes Problem
# T_A04 :  Zeit_Seite_A04_Wichtigstes Problem, Lösungskompetenz
# T13_A04 :  Zeit_kumuliert_A04_Wichtigstes Problem, Lösungskompetenz
# T_A03 :  Zeit_Seite_A03_Wichtigstes Problem
# A03_c2 :  Wichtigstes Problem: 2. Nennung
# A03_c3 :  Wichtigstes Problem: 3. Nennung
# A04c :  Wichtigstes Problem, Loesungskompetenz (Version B)
# A03_c4 :  Wichtigstes Problem: 4. Nennung
# A03_c1 :  Wichtigstes Problem: 1. Nennung
# T12_A03 :  Zeit_kumuliert_A03_Wichtigstes Problem
# A04 :  Wichtigstes Problem, Loesungskompetenz (Version A)
#
#
# 5726
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10s :  Wichtigstes Problem
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)
#
#
# 5733
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c3 :  Wichtigstes Problem (Codierung 3)
#
#
# 5725
# t10c1 :  Wichtigstes Problem (Codierung 1)
# t10c4 :  Wichtigstes Problem (Codierung 4)
# t11a :  Wichtigstes Problem, Loesungskompetenz (Version A)
# t10s :  Wichtigstes Problem
# t10c2 :  Wichtigstes Problem (Codierung 2)
# t11b :  Wichtigstes Problem, Loesungskompetenz (Version B)
# t10c3 :  Wichtigstes Problem (Codierung 3)
# t10c5 :  Wichtigstes Problem (Codierung 5)

# %%
#store variable names belonging to the first coding of the issue question in a dictionary for each wave
issue_comp8 = {}

for l in labels:
    v_l = l.variable_labels()
    for key, val in v_l.items():
        if val == 'Wichtigstes Problem (1. Codierung)' or val == 'Wichtigstes Problem (Codierung)' or val == 'Wichtigstes Problem: 1. Nennung' or val == 'Wichtigstes Problem: 1. Codierung' or val == 'Wichtigstes Problem (Codierung 1)':
            issue_comp8[labels.index(l)] = key
            
assert len(issue_comp8) == len(filenames)

# %%
# correction for wrong end date in first wave
# for-loop as file order can vary by system
for df in dataframes:
    if np.any(df.field=="2009-04-30 bis 2011-05-12"):
        df.field = '2009-04-30 bis 2009-05-12'
        break

# %%
#store variable name belonging to all codings of the issue question in a dictionary for each wave
issue_comp8_all_mentions = {}

for l in labels:
    v_l = l.variable_labels()
    issue_comp8_all_mentions[labels.index(l)] = []
    for key, val in v_l.items():
        if val == 'Wichtigstes Problem (1. Codierung)' or val == 'Wichtigstes Problem (2. Codierung)' or val == 'Wichtigstes Problem (3. Codierung)' or val == 'Wichtigstes Problem (4. Codierung)' or val == 'Wichtigstes Problem (5. Codierung)' or val == 'Wichtigstes Problem (6. Codierung)' or val == 'Wichtigstes Problem (Codierung)' or val == 'Wichtigstes Problem: 1. Nennung' or val == 'Wichtigstes Problem: 2. Nennung' or val == 'Wichtigstes Problem: 3. Nennung' or val == 'Wichtigstes Problem: 4. Nennung' or val == 'Wichtigstes Problem: 5. Nennung' or val == 'Wichtigstes Problem: 6. Nennung' or val == 'Wichtigstes Problem: 7. Nennung' or val == 'Wichtigstes Problem: 8. Nennung' or val == 'Wichtigstes Problem: 1. Codierung' or val == 'Wichtigstes Problem: 2. Codierung' or val == 'Wichtigstes Problem: 3. Codierung' or val == 'Wichtigstes Problem: 4. Codierung' or val == 'Wichtigstes Problem: 5. Codierung' or val == 'Wichtigstes Problem: 6. Codierung' or val == 'Wichtigstes Problem: 7. Codierung' or val == 'Wichtigstes Problem: 8. Codierung' or val == 'Wichtigstes Problem: 9. Codierung' or val == 'Wichtigstes Problem: 10. Codierung' or val == 'Wichtigstes Problem: 11. Codierung' or val == 'Wichtigstes Problem: 12. Codierung' or val == 'Wichtigstes Problem (Codierung 1)' or val == 'Wichtigstes Problem (Codierung 2)' or val == 'Wichtigstes Problem (Codierung 3)' or val == 'Wichtigstes Problem (Codierung 4)' or val == 'Wichtigstes Problem (Codierung 5)'or val == 'Wichtigstes Problem (Codierung 6)':
            issue_comp8_all_mentions[labels.index(l)].append(key)
            
assert len(issue_comp8_all_mentions) == len(filenames)

# %%
# store the names of the variables concerning the voting districts/federal states for each wave in a dictionary
elecdist_comp8 = {}
ec8 = {}
for l in labels:
    v_l = l.variable_labels()
    for key, val in v_l.items():
        if key == 'elecdist' or key == 'wahlkreis' or key == 'Buland':
            elecdist_comp8[dataframes[labels.index(l)].loc[0, 'study']] = key
            ec8[labels.index(l)] = key          
            
assert len(ec8) == len(filenames) == len(dataframes)

# %%
#define a function to upscale the voting districts to the level of federal states
def get_states(row, zeile):
    if zeile == 'wahlkreis':
        if 1 <= row <= 11:
            return 'SH'
        elif 12 <= row <= 17:
            return 'MV'
        elif 18 <= row <= 23:
            return('HH')
        elif 24 <= row <= 53:
            return('NI')
        elif 54 <= row <= 55:
            return('HB')
        elif 56 <= row <= 65:
            return('BB')
        elif 66 <= row <= 74:
            return('ST')
        elif 75 <= row <= 86:
            return('BE')
        elif 87 <= row <= 150:
            return('NW')
        elif 151 <= row <= 166:
            return('SN')
        elif 167 <= row<= 188:
            return('HE')
        elif 189 <= row <= 196:
            return('TH')
        elif 197 <= row <= 211:
            return('RP')
        elif 212 <= row <= 257:
            return('BY')
        elif 258 <= row <= 295:
            return('BW')
        elif 296 <= row <= 299:
            return('SL')
        else:
            return(np.nan)
    
    elif zeile == 'elecdist':
        if 1 <= row <= 11:
            return('SH')
        elif 12 <= row <= 17:
            return('MV')
        elif 18 <= row <= 23:
            return('HH')
        elif 24 <= row <= 53:
            return('NI')
        elif 54 <= row <= 55:
            return('HB')
        elif 56 <= row <= 65:
            return('BB')
        elif 66 <= row <= 74:
            return('ST')
        elif 75 <= row <= 86:
            return('BE')
        elif 87 <= row <= 150:
            return('NW')
        elif 151 <= row <= 166:
            return('SN')
        elif 167 <= row <= 188:
            return('HE')
        elif 189 <= row <= 196:
            return('TH')
        elif 197 <= row <= 211:
            return('RP')
        elif 212 <= row <= 257:
            return('BY')
        elif 258 <= row <= 295:
            return('BW')
        elif 296 <= row <= 299:
            return('SL')
        else:
            return(np.nan)
    
    elif zeile == 'Buland':
        if row == 1:
            return('BW')
        elif row == 2:
            return('BY')
        elif row == 3:
            return('BE')
        elif row == 4:
            return('BB')
        elif row == 5:
            return('HB')
        elif row == 6:
            return('HH')
        elif row == 7:
            return('HE')
        elif row == 8:
            return('MV')
        elif row == 9:
            return('NI')
        elif row == 10:
            return('NW')
        elif row == 11:
            return('RP')
        elif row == 12:
            return('SL')
        elif row == 13:
            return('SN')
        elif row == 14:
            return('ST')
        elif row == 15:
            return('SH')
        elif row == 16:
            return('TH')
        else:
            return(np.nan)
    else:
        return(np.nan)

# %%
#join all columns regarding the issue question of all dataframes in one dataframe

issue_df = pd.DataFrame(columns=['field','issue_code', 'elecdist', 'lfdn'])
for key, val in issue_comp8_all_mentions.items():
    for v in val:
        df = dataframes[key].loc[:, ['study', 'field', v, 'lfdn']]
        df['study'] = df['study'].apply( lambda study: 'ZA'+str(int(study)) )         
        df['elecdist'] = dataframes[key].loc[:, ec8[key]]
        df['state'] = dataframes[key].loc[:, ec8[key]].apply(get_states, zeile=ec8[key])
        df.columns = ['wave_code', 'field', 'issue_code','lfdn', 'elecdist', 'state']
        issue_df = issue_df.append(df)
        
issue_df.head()
# Out:
#   elecdist                      field issue_code lfdn state wave_code
# 0       50  2016-06-03 bis 2016-06-17       3753    1    NI    ZA5732
# 1      267  2016-06-03 bis 2016-06-17       3753    2    BW    ZA5732
# 2       52  2016-06-03 bis 2016-06-17       2438    3    NI    ZA5732
# 3      209  2016-06-03 bis 2016-06-17       3700    4    RP    ZA5732
# 4      168  2016-06-03 bis 2016-06-17       3753    5    HE    ZA5732

# %%
#convert code numbers into categories in the way Arnim et al. did it in BTW2013 paper

def get_issue_category_asinbtw13(row, zeile):
    if str(row)[:1] == '1' and len(str(row)) <=4:
        return('Politics')
    elif str(row)[:1] == '2':
        return('Polity')
    elif str(row)[:3] == '431':
        return('Budget and Debt')
    elif str(row)[:3] == '433' :
        return('Currency and Euro')
    elif str(row)[:2] in ['39' , '40']:
        return('Economy')
    elif str(row)[:2] == '41' :
        return('Education')
    elif str(row)[:2] == '36' :
        return('Environment')
    elif str(row)[:3] == '371' :
        return('Family Policy')
    elif str(row)[:3] in ['310','310', '312', '316', '317', '318', '329'  '330', '331', '332', '333', '339']:
         return('Foreign Policy (Defense)')    
    elif str(row)[:3] == '311' :
        return('Foreign Policy (Europe)')    
    elif str(row)[:3]  in ['430' ,'439']:
        return('General Fiscal Policy')    
    elif str(row)[:3]  in ['370', '372', '373', '378', '379'] :
        return('General Social Policy')    
    elif str(row)[:3]  in ['374' ,'376','377'] :
        return('Health Care and Pensions')      
    elif str(row)[:2] == '35' :
        return('Infrastructure')    
    elif str(row)[:2] == '38' :
        return('Labor Market')    
    elif str(row)[:2] == '34' :
        return('Law and Order')    
    elif str(row)[:3] == '375' :
        return('Migration and Integration')     
    elif str(row)[:3] == '432' :
        return('Taxes') 
    else:
        return(np.nan)

# %%
issue_df['issue_code'] = issue_df['issue_code'].apply(get_issue_category_asinbtw13, zeile='issue_code')

issue_df['issue_code'] = issue_df['issue_code'].str.lower()

pd.to_numeric(issue_df.issue_code.value_counts().index, errors='coerce').unique().sort_values()#[issue_df.issue_code.value_counts()]

issue_df['field'] = issue_df.field.str.replace('bis', 'to')

# %%
issue_df['year'] = issue_df.field.map(lambda x: re.match('\d\d\d\d', x).group(0))
issue_df['start_of_wave'] = issue_df.field.map(lambda x: re.match('\d\d\d\d\-\d\d\-\d\d', x).group(0))
issue_df['start_of_wave'] = pd.to_datetime(issue_df['start_of_wave'])

# %%
issue_df.issue_code.unique()
# Out:
# array(['migration and integration', 'polity', 'general social policy',
#        'infrastructure', 'politics', 'education', 'law and order',
#        'foreign policy (europe)', nan, 'labor market',
#        'health care and pensions', 'economy', 'foreign policy (defense)',
#        'budget and debt', 'currency and euro', 'general fiscal policy',
#        'environment', 'taxes', 'family policy'], dtype=object)

# %%
issue_df.to_csv('data/C8_issue_df.csv',index=False)
issue_df.head()
# Out:
#   elecdist                     field                 issue_code lfdn state  \
# 0       50  2016-06-03 to 2016-06-17  migration and integration    1    NI
# 1      267  2016-06-03 to 2016-06-17  migration and integration    2    BW
# 2       52  2016-06-03 to 2016-06-17                     polity    3    NI
# 3      209  2016-06-03 to 2016-06-17      general social policy    4    RP
# 4      168  2016-06-03 to 2016-06-17  migration and integration    5    HE
#
#   wave_code  year start_of_wave
# 0    ZA5732  2016    2016-06-03
# 1    ZA5732  2016    2016-06-03
# 2    ZA5732  2016    2016-06-03
# 3    ZA5732  2016    2016-06-03
# 4    ZA5732  2016    2016-06-03

# %% [markdown]
# # Now merge with raw text

# %%
missing_raw_text_filenames = glob(local_folder+'/issue_item_raw_text_if_missing_in_dataset/*.csv')
missing_raw_text_filecodes = [ fn.split('/')[-1][:6] for fn in missing_raw_text_filenames ]

missing_raw_text_filenames
# Out:
# ['./issue_item_raw_text_if_missing_in_dataset/ZA6815_v1-0-0_open-ended.csv',
#  './issue_item_raw_text_if_missing_in_dataset/ZA5734_open-ended_v1-0-0.csv',
#  './issue_item_raw_text_if_missing_in_dataset/ZA5732_open-ended_v1-0-0.csv',
#  './issue_item_raw_text_if_missing_in_dataset/ZA6817_v1-0-0_open-ended.csv',
#  './issue_item_raw_text_if_missing_in_dataset/ZA6816_v1-0-0_open-ended.csv',
#  './issue_item_raw_text_if_missing_in_dataset/ZA5733_open-ended_v1-0-0.csv',
#  './issue_item_raw_text_if_missing_in_dataset/ZA5731_open-ended_v1-1-0.csv',
#  './issue_item_raw_text_if_missing_in_dataset/ZA5720_v3-0-0_open-ended.csv']

# %%
missing_raw_text = { filecode:pd.read_csv(filename, sep=';', encoding='latin1') \
                     for filecode,filename in zip(missing_raw_text_filecodes, missing_raw_text_filenames) }

missing_raw_text[missing_raw_text_filecodes[0]].head()
# Out:
#    lfdn                                t10s  \
# 0   935  Vertrauensverlust und Desinteresse
# 1   346                        Schulbildung
# 2   747               Sozialer zusammenhalt
# 3   525              Stabilisierung Europas
# 4   443                  Flüchtlingspolitik
#
#                                      t12s
# 0                   Soziale Gerechtigkeit
# 1             Integration und Zuwanderung
# 2                              Popolismus
# 3                      Flüchtlingspolitik
# 4  Rechtsruck in der Politik "AfD-Wähler"

# %%
# See which waves have a field called 'Wichtigstes Problem'

out_strs = []
for filename,l in zip(filenames,labels):
    out_str = dataframes[labels.index(l)].loc[0, 'field'].replace('bis','to')+'-'+filename[15:]
    
    vardict = l.variable_labels()
    for key, val in vardict.items():
        if 'Wichtigstes Problem' == val:
            out_str += ' - '+str(key)+': '+str(val) 
    if filename.split('/')[-1][:6] in missing_raw_text_filecodes:
        out_str += ' - '+'text in '+filename.split('/')[-1][:6]+'.csv'
    out_strs += [out_str]

out_strs = sorted(out_strs)
out_strs
# Out:
# ['2009-04-30 to 2009-05-12-ZA5334_v3-0-0.dta',
#  '2009-05-27 to 2009-06-05-ZA5335_v4-0-0.dta',
#  '2009-07-03 to 2009-07-13-ZA5336_v4-0-0.dta',
#  '2009-07-31 to 2009-08-11-ZA5337_v3-0-0.dta',
#  '2009-08-24 to 2009-09-01-ZA5338_v3-1-0.dta',
#  '2009-09-18 to 2009-09-27-ZA5339_v3-0-0.dta - a03s: Wichtigstes Problem',
#  '2009-09-29 to 2009-10-08-ZA5340_v4-0-0.dta - a03: Wichtigstes Problem',
#  '2009-12-10 to 2009-12-20-ZA5341_v2-0-0.dta - A03s: Wichtigstes Problem',
#  '2010-04-15 to 2010-04-23-ZA5342_v2-0-0.dta - A03s: Wichtigstes Problem',
#  '2010-06-24 to 2010-07-05-ZA5343_v2-0-0.dta - A03s: Wichtigstes Problem',
#  '2010-09-16 to 2010-09-26-ZA5344_v2-0-0.dta - A03s: Wichtigstes Problem',
#  '2010-12-09 to 2010-12-19-ZA5345_v2-0-0.dta - A03s: Wichtigstes Problem',
#  '2011-03-09 to 2011-03-19-ZA5346_v2-1-0.dta - A03s: Wichtigstes Problem',
#  '2011-05-23 to 2011-06-03-ZA5347_v2-0-0.dta - A03s: Wichtigstes Problem',
#  '2011-08-24 to 2011-09-03-ZA5348_v2-0-0.dta - a03s: Wichtigstes Problem',
#  '2011-12-08 to 2011-12-18-ZA5349_v2-0-0.dta - A03s: Wichtigstes Problem',
#  '2012-05-02 to 2012-05-15-ZA5350_v1-2-0.dta - t10s: Wichtigstes Problem',
#  '2012-09-17 to 2012-10-01-ZA5351_v2-0-0.dta - t10s: Wichtigstes Problem',
#  '2013-01-04 to 2013-01-19-ZA5719_v2-0-0.dta - t10s: Wichtigstes Problem',
#  '2013-05-24 to 2013-06-08-ZA5720_v2-0-0.dta - text in ZA5720.csv',
#  '2013-09-06 to 2013-09-21-ZA5721_v3-1-0.dta - t10s: Wichtigstes Problem',
#  '2013-11-29 to 2013-12-13-ZA5722_v3-0-0.dta - t10s: Wichtigstes Problem',
#  '2014-02-21 to 2014-03-07-ZA5723_v2-0-0.dta - t10s: Wichtigstes Problem',
#  '2014-05-09 to 2014-05-23-ZA5724_v1-2-0.dta - t10s: Wichtigstes Problem',
#  '2014-08-29 to 2014-09-13-ZA5725_v2-1-0.dta - t10s: Wichtigstes Problem',
#  '2014-11-21 to 2014-12-05-ZA5726_v1-1-0.dta - t10s: Wichtigstes Problem',
#  '2015-02-27 to 2015-03-13-ZA5727_v1-1-0.dta - t10s: Wichtigstes Problem',
#  '2015-06-05 to 2015-06-19-ZA5728_v2-1-0.dta - t10s: Wichtigstes Problem',
#  '2015-09-11 to 2015-09-25-ZA5729_v1-1-0.dta - t10s: Wichtigstes Problem',
#  '2015-12-04 to 2015-12-18-ZA5730_v1-2-0.dta - t10s: Wichtigstes Problem',
#  '2016-02-26 to 2016-03-11-ZA5731_v1-1-0.dta - text in ZA5731.csv',
#  '2016-06-03 to 2016-06-17-ZA5732_v1-0-0.dta - text in ZA5732.csv',
#  '2016-08-19 to 2016-09-02-ZA5733_v1-0-0.dta - text in ZA5733.csv',
#  '2016-12-02 to 2016-12-16-ZA5734_v1-0-0.dta - text in ZA5734.csv',
#  '2017-03-17 to 2017-03-31-ZA6815_v1-0-0.dta - text in ZA6815.csv',
#  '2017-06-16 to 2017-06-30-ZA6816_v1-0-0.dta - text in ZA6816.csv',
#  '2017-09-12 to 2017-09-23-ZA6817_v1-0-0.dta - text in ZA6817.csv']

# %%
# Show labels of variables concerning most important problem for wave 'idx'
vardict_vls = [pd.read_stata(i, iterator=True) for i in filenames]

l = labels[idx]
print(dataframes[labels.index(l)].loc[0, 'study'])

vardict = l.variable_labels()
for key, val in vardict.items():
    if 'Wichtigstes Problem' in val:
        print(key, ': ', val)           
        
keys = [ key for (key, val) in labels[idx].variable_labels().items() if 'Wichtigstes Problem' in val ]

dataframes[labels.index(l)].filter(keys).head()
# Out:
# 5340
# T_A04 :  Zeit_Seite_A04_Loesungskompetenz: Wichtigstes Problem
# a03_c2 :  Wichtigstes Problem (2. Codierung)
# a04 :  Loesungskompetenz: Wichtigstes Problem (Version A)
# T_A03 :  Zeit_Seite_A03_Wichtigstes Problem
# a03 :  Wichtigstes Problem
# T29_A04 :  Zeit_kumuliert_A04_Loesungskompetenz: Wichtigstes Problem
# a04c :  Loesungskompetenz: Wichtigstes Problem (Version B)
# T28_A03 :  Zeit_kumuliert_A03_Wichtigstes Problem
# a03_c3 :  Wichtigstes Problem (3. Codierung)
# a03_c1 :  Wichtigstes Problem (1. Codierung)
# a03_c4 :  Wichtigstes Problem (4. Codierung)
#    T_A04  a03_c2   a04  T_A03                   a03  T29_A04  a04c  T28_A03  \
# 0     16   10000     5      9      Arbeitslosigkeit      172     5      156
# 1      0   10000  1000      2                    99        0  1000      156
# 2      8   10000   808     28   Die Arbeislosigkeit      396   809      388
# 3      2   10000     7     10  Wirtschaftliche Lage      121     7      119
# 4      0   10000  1000      3                    99        0  1000      278
#
#    a03_c3  a03_c1  a03_c4
# 0   10000    3810   10000
# 1   10000    9999   10000
# 2   10000    3810   10000
# 3   10000    3910   10000
# 4   10000    9999   10000

# %% [markdown]
# ## Get all text entries of every wave

# %%
raw_texts = []

for filename,l in zip(filenames,labels):
    time_window = dataframes[labels.index(l)].loc[0, 'field'].replace('bis','to')
    fn = filename[15:21]
    out_str = time_window+'-'+fn
    
    vardict = l.variable_labels()
    for key, val in vardict.items():
        if 'Wichtigstes Problem' == val:
            out_str += ' - '+str(key)+': '+str(val)
            print('Processing: '+out_str)
            
            df = dataframes[labels.index(l)].filter(['lfdn',key])#.set_index('lfdn')
            raw_texts += [( time_window, fn, key, df, False )]
            
    if filename.split('/')[-1][:6] in missing_raw_text_filecodes:
        out_str += ' - '+'text in '+filename.split('/')[-1][:6]+'.csv'
        print('Processing: '+out_str)
        
        df = missing_raw_text[fn].filter(['lfdn','t10s'])#.set_index('lfdn')
        raw_texts += [( time_window, fn, key, df, True )]

raw_texts.sort()
# Out:
# Processing: 2016-06-03 to 2016-06-17-ZA5732 - text in ZA5732.csv
# Processing: 2010-06-24 to 2010-07-05-ZA5343 - A03s: Wichtigstes Problem
# Processing: 2017-03-17 to 2017-03-31-ZA6815 - text in ZA6815.csv
# Processing: 2012-05-02 to 2012-05-15-ZA5350 - t10s: Wichtigstes Problem
# Processing: 2013-09-06 to 2013-09-21-ZA5721 - t10s: Wichtigstes Problem
# Processing: 2015-09-11 to 2015-09-25-ZA5729 - t10s: Wichtigstes Problem
# Processing: 2015-02-27 to 2015-03-13-ZA5727 - t10s: Wichtigstes Problem
# Processing: 2010-12-09 to 2010-12-19-ZA5345 - A03s: Wichtigstes Problem
# Processing: 2016-12-02 to 2016-12-16-ZA5734 - text in ZA5734.csv
# Processing: 2016-02-26 to 2016-03-11-ZA5731 - text in ZA5731.csv
# Processing: 2017-09-12 to 2017-09-23-ZA6817 - text in ZA6817.csv
# Processing: 2010-09-16 to 2010-09-26-ZA5344 - A03s: Wichtigstes Problem
# Processing: 2009-12-10 to 2009-12-20-ZA5341 - A03s: Wichtigstes Problem
# Processing: 2013-11-29 to 2013-12-13-ZA5722 - t10s: Wichtigstes Problem
# Processing: 2009-09-29 to 2009-10-08-ZA5340 - a03: Wichtigstes Problem
# Processing: 2017-06-16 to 2017-06-30-ZA6816 - text in ZA6816.csv
# Processing: 2015-12-04 to 2015-12-18-ZA5730 - t10s: Wichtigstes Problem
# Processing: 2013-01-04 to 2013-01-19-ZA5719 - t10s: Wichtigstes Problem
# Processing: 2011-12-08 to 2011-12-18-ZA5349 - A03s: Wichtigstes Problem
# Processing: 2014-02-21 to 2014-03-07-ZA5723 - t10s: Wichtigstes Problem
# Processing: 2011-05-23 to 2011-06-03-ZA5347 - A03s: Wichtigstes Problem
# Processing: 2012-09-17 to 2012-10-01-ZA5351 - t10s: Wichtigstes Problem
# Processing: 2013-05-24 to 2013-06-08-ZA5720 - text in ZA5720.csv
# Processing: 2014-05-09 to 2014-05-23-ZA5724 - t10s: Wichtigstes Problem
# Processing: 2011-03-09 to 2011-03-19-ZA5346 - A03s: Wichtigstes Problem
# Processing: 2011-08-24 to 2011-09-03-ZA5348 - a03s: Wichtigstes Problem
# Processing: 2015-06-05 to 2015-06-19-ZA5728 - t10s: Wichtigstes Problem
# Processing: 2009-09-18 to 2009-09-27-ZA5339 - a03s: Wichtigstes Problem
# Processing: 2010-04-15 to 2010-04-23-ZA5342 - A03s: Wichtigstes Problem
# Processing: 2014-11-21 to 2014-12-05-ZA5726 - t10s: Wichtigstes Problem
# Processing: 2016-08-19 to 2016-09-02-ZA5733 - text in ZA5733.csv
# Processing: 2014-08-29 to 2014-09-13-ZA5725 - t10s: Wichtigstes Problem

# %%
# Make single dataset with all responses
df_all_raw_texts = pd.DataFrame()
for tup in raw_texts:
    time_window, fn, key, df, miss = tup
    df.columns.values[1] = 'text'
    df['time_window'] = time_window
    df['wave_code']   = fn
    df['answer_key']  = key
    # df['originally_missing_in_dataset'] = miss # Uncomment if it's useful to know which file it came from
    df_all_raw_texts = df_all_raw_texts.append(df, ignore_index=True)

# %% [markdown]
# # Combine that with the labels given to each answer

# %%
wc1 = set(df_all_raw_texts.wave_code.values)
wc2 = set(issue_df.wave_code.values)

print("We have the labels but not the text:")
print(wc2.difference(wc1),'\n')

print("We have the text but not the labels:")
print(wc1.difference(wc2))
# Out:
# We have the labels but not the text:
# {'ZA5335', 'ZA5336', 'ZA5338', 'ZA5337', 'ZA5334'}
#
# We have the text but not the labels:
# set()

# %%
all_codes = []
for index, row in df_all_raw_texts.iterrows():
    if index % 500 == 0:
        print(index,'done')
    lfdn = row.lfdn
    wc = row.wave_code
    df = issue_df[ (issue_df.wave_code==wc) & (issue_df.lfdn==lfdn)  ]
    codes = df.issue_code.unique()
    all_codes += [ list(codes) ]

# %%
df_all_raw_texts['tags'] = all_codes
df_all_raw_texts['tags'] = df_all_raw_texts['tags'].apply( lambda x: '/'.join([ i for i in x if type(i)==str ]) )
df_all_raw_texts['tags'] = df_all_raw_texts['tags'].apply( lambda x: np.nan if x=='' else x )

df_all_raw_texts.to_csv('data/C8_all_raw_texts_and_labels.csv', sep='\t', encoding='utf-8')

# %% [markdown]
# The reason some entries have many tags comes from waves with multiple label entries, such as:
# - 'A03_c1' - 'Wichtigstes Problem: 1. Codierung'
# - 'A03_c2' - 'Wichtigstes Problem: 2. Codierung'
# - ...
# - 'A03_c8' - 'Wichtigstes Problem: 8. Codierung'

# %%
df_all_raw_texts.head()
# Out:
#     lfdn                                               text  \
# 0  177.0                                                 99
# 1  178.0                              Die arbeitslosigkeit.
# 2  179.0                                                 ka
# 3  180.0  Dass die Finanzen geordnet werden und keine Ne...
# 4  181.0                    Schulpolitik sollte besser sein
#
#                 time_window wave_code answer_key             tags
# 0  2009-09-18 to 2009-09-27    ZA5339       a03s              NaN
# 1  2009-09-18 to 2009-09-27    ZA5339       a03s     labor market
# 2  2009-09-18 to 2009-09-27    ZA5339       a03s              NaN
# 3  2009-09-18 to 2009-09-27    ZA5339       a03s  budget and debt
# 4  2009-09-18 to 2009-09-27    ZA5339       a03s        education
