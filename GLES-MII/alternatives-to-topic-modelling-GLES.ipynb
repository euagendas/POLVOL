# %%
import os
import string
import nltk
#nltk.download('stopwords')
#nltk.download('punkt')
import time

import pandas as pd
import numpy as np
from functools import reduce
from scipy.stats import entropy
from datetime import datetime

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context("poster", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.mpl.rc("figure", figsize=(9,6))

import warnings; warnings.filterwarnings('ignore')

# %%
def tokenize(text):
    stopwords = set(nltk.corpus.stopwords.words('german'))
    with open('../der_spiegel/german_stopwords.txt') as f:
        more_stopwords = [ line[:-1] for line in f ]
    stopwords = stopwords.union(set(more_stopwords))
    
    minlength = 3
    
    invalidChars = { '¡', '§', '©', '\xad', '°', '²', '³', 'µ', '¹', '¿', '×', '\u200b', 
                    '•', '‣', '…', '⁄', '₂', '€', '™', '▇', '■', '▶', '◆', '●', '★', '✽',
                    '❏', '➝', '主', '原', '年', '後', '歸', '物', '舧', '舰'}
    invalidChars = invalidChars.union(set(string.punctuation.replace("-", "–„“")))
    for token in nltk.word_tokenize(text):
        t = token.lower()
        if (len(t)<minlength) or (t in stopwords) or (t.replace('ß','ss') in stopwords) \
        or (t in string.punctuation) or (t[0] in string.punctuation) \
        or any(char in invalidChars for char in token):
            continue
        yield t
        
def normalise(vec):
    return vec / np.dot(vec,vec)

def combine_vectors(vectors):
    return normalise(np.sum(vectors, axis=0))

def important_words(vectorizer, vec, n):
    return sorted(zip(vectorizer.get_feature_names(), vec), key=lambda x:x[1], reverse=True)[:n]

# %%
df_all_raw_texts = pd.read_csv('data/C8_all_raw_texts_and_labels.csv', sep='\t', encoding='utf-8', index_col=0)
df_all_raw_texts = df_all_raw_texts[pd.notnull(df_all_raw_texts['text'])]
df_all_raw_texts.head()
# Out:
#     lfdn                                               text  \
# 0  177.0                                                 99
# 1  178.0                              Die arbeitslosigkeit.
# 2  179.0                                                 ka
# 3  180.0  Dass die Finanzen geordnet werden und keine Ne...
# 4  181.0                    Schulpolitik sollte besser sein
#
#                 time_window wave_code answer_key             tags
# 0  2009-09-18 to 2009-09-27    ZA5339       a03s              NaN
# 1  2009-09-18 to 2009-09-27    ZA5339       a03s     labor market
# 2  2009-09-18 to 2009-09-27    ZA5339       a03s              NaN
# 3  2009-09-18 to 2009-09-27    ZA5339       a03s  budget and debt
# 4  2009-09-18 to 2009-09-27    ZA5339       a03s        education

# %%
df_all_raw_texts[df_all_raw_texts.wave_code=='ZA6817'].head().text
# Out:
# 34184                                Soziale Gerechtigkeit
# 34185    groe Schere zwischen arm und reich /Ungerecht...
# 34186                                           Sicherheit
# 34187                                              Bildung
# 34188                                              Bildung
# Name: text, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
start = time.time()

# list of text documents
text = df_all_raw_texts.text.values
doc_ids = df_all_raw_texts.index.values

# create the transform
vectorizer = CountVectorizer(tokenizer=tokenize, min_df=0.005, max_df=0.8)

# tokenize and build vocab
vectorizer.fit(text)

# summarize
#print(vectorizer.vocabulary_)

# encode document-term matrix
dtm = vectorizer.transform(text)

# summarize encoded vector
print('Shape of document-term matrix (documents, tokens):', dtm.shape)
print('Total number of tokens:', dtm.sum() )
#print(type(dtm))
#print(dtm.toarray())

end = time.time()
print((end - start)/60.0,'minutes')
# Out:
# Shape of document-term matrix (documents, tokens): (34149, 55)
# Total number of tokens: 24862
# 1.1572377999623618 minutes

# %%
import lda

n_topics = 15
topic_model = lda.LDA(n_topics=n_topics, n_iter=1500, random_state=1)

# %%
start = time.time()

document_topic_distributions = topic_model.fit_transform(dtm)

end = time.time()
print((end - start)/60.0,'minutes')
# Out:
# INFO:lda:n_documents: 34149
# INFO:lda:vocab_size: 55
# INFO:lda:n_words: 24862
# INFO:lda:n_topics: 10
# INFO:lda:n_iter: 1500
# WARNING:lda:all zero row in document-term matrix found
# INFO:lda:<0> log likelihood: -159794
# INFO:lda:<10> log likelihood: -132133
# INFO:lda:<20> log likelihood: -123203
# INFO:lda:<30> log likelihood: -117534
# INFO:lda:<40> log likelihood: -113410
# INFO:lda:<50> log likelihood: -110649
# INFO:lda:<60> log likelihood: -108695
# INFO:lda:<70> log likelihood: -107396
# INFO:lda:<80> log likelihood: -106725
# INFO:lda:<90> log likelihood: -106626
# INFO:lda:<100> log likelihood: -106277
# INFO:lda:<110> log likelihood: -105936
# INFO:lda:<120> log likelihood: -105458
# INFO:lda:<130> log likelihood: -105305
# INFO:lda:<140> log likelihood: -105115
# INFO:lda:<150> log likelihood: -104403
# INFO:lda:<160> log likelihood: -103985
# INFO:lda:<170> log likelihood: -103976
# INFO:lda:<180> log likelihood: -104281
# INFO:lda:<190> log likelihood: -103997
# INFO:lda:<200> log likelihood: -103967
# INFO:lda:<210> log likelihood: -103735
# INFO:lda:<220> log likelihood: -104050
# INFO:lda:<230> log likelihood: -103780
# INFO:lda:<240> log likelihood: -103644
# INFO:lda:<250> log likelihood: -103726
# INFO:lda:<260> log likelihood: -103582
# INFO:lda:<270> log likelihood: -103396
# INFO:lda:<280> log likelihood: -103395
# INFO:lda:<290> log likelihood: -103566
# INFO:lda:<300> log likelihood: -103624
# INFO:lda:<310> log likelihood: -103838
# INFO:lda:<320> log likelihood: -103871
# INFO:lda:<330> log likelihood: -103709
# INFO:lda:<340> log likelihood: -103469
# INFO:lda:<350> log likelihood: -102984
# INFO:lda:<360> log likelihood: -102969
# INFO:lda:<370> log likelihood: -103775
# INFO:lda:<380> log likelihood: -102995
# INFO:lda:<390> log likelihood: -102731
# INFO:lda:<400> log likelihood: -102844
# INFO:lda:<410> log likelihood: -103321
# INFO:lda:<420> log likelihood: -103140
# INFO:lda:<430> log likelihood: -103134
# INFO:lda:<440> log likelihood: -103008
# INFO:lda:<450> log likelihood: -103092
# INFO:lda:<460> log likelihood: -103049
# INFO:lda:<470> log likelihood: -103610
# INFO:lda:<480> log likelihood: -103543
# INFO:lda:<490> log likelihood: -103651
# INFO:lda:<500> log likelihood: -103219
# INFO:lda:<510> log likelihood: -103467
# INFO:lda:<520> log likelihood: -103051
# INFO:lda:<530> log likelihood: -103277
# INFO:lda:<540> log likelihood: -103457
# INFO:lda:<550> log likelihood: -103132
# INFO:lda:<560> log likelihood: -103518
# INFO:lda:<570> log likelihood: -103582
# INFO:lda:<580> log likelihood: -103793
# INFO:lda:<590> log likelihood: -103822
# INFO:lda:<600> log likelihood: -103498
# INFO:lda:<610> log likelihood: -103741
# INFO:lda:<620> log likelihood: -103513
# INFO:lda:<630> log likelihood: -103932
# INFO:lda:<640> log likelihood: -103617
# INFO:lda:<650> log likelihood: -104340
# INFO:lda:<660> log likelihood: -103901
# INFO:lda:<670> log likelihood: -103922
# INFO:lda:<680> log likelihood: -103770
# INFO:lda:<690> log likelihood: -103898
# INFO:lda:<700> log likelihood: -103775
# INFO:lda:<710> log likelihood: -103849
# INFO:lda:<720> log likelihood: -104031
# INFO:lda:<730> log likelihood: -103926
# INFO:lda:<740> log likelihood: -103858
# INFO:lda:<750> log likelihood: -103703
# INFO:lda:<760> log likelihood: -103566
# INFO:lda:<770> log likelihood: -103787
# INFO:lda:<780> log likelihood: -104174
# INFO:lda:<790> log likelihood: -103780
# INFO:lda:<800> log likelihood: -103714
# INFO:lda:<810> log likelihood: -104060
# INFO:lda:<820> log likelihood: -104066
# INFO:lda:<830> log likelihood: -103787
# INFO:lda:<840> log likelihood: -103446
# INFO:lda:<850> log likelihood: -103542
# INFO:lda:<860> log likelihood: -103378
# INFO:lda:<870> log likelihood: -103546
# INFO:lda:<880> log likelihood: -103443
# INFO:lda:<890> log likelihood: -104062
# INFO:lda:<900> log likelihood: -103829
# INFO:lda:<910> log likelihood: -103541
# INFO:lda:<920> log likelihood: -104145
# INFO:lda:<930> log likelihood: -103828
# INFO:lda:<940> log likelihood: -104128
# INFO:lda:<950> log likelihood: -103970
# INFO:lda:<960> log likelihood: -103694
# INFO:lda:<970> log likelihood: -103938
# INFO:lda:<980> log likelihood: -104149
# INFO:lda:<990> log likelihood: -104379
# INFO:lda:<1000> log likelihood: -104428
# INFO:lda:<1010> log likelihood: -104487
# INFO:lda:<1020> log likelihood: -104616
# INFO:lda:<1030> log likelihood: -104197
# INFO:lda:<1040> log likelihood: -104027
# INFO:lda:<1050> log likelihood: -104199
# INFO:lda:<1060> log likelihood: -104182
# INFO:lda:<1070> log likelihood: -103967
# INFO:lda:<1080> log likelihood: -104244
# INFO:lda:<1090> log likelihood: -104198
# INFO:lda:<1100> log likelihood: -104197
# INFO:lda:<1110> log likelihood: -104708
# INFO:lda:<1120> log likelihood: -104293
# INFO:lda:<1130> log likelihood: -104788
# INFO:lda:<1140> log likelihood: -104463
# INFO:lda:<1150> log likelihood: -104506
# INFO:lda:<1160> log likelihood: -104387
# INFO:lda:<1170> log likelihood: -104123
# INFO:lda:<1180> log likelihood: -104283
# INFO:lda:<1190> log likelihood: -103757
# INFO:lda:<1200> log likelihood: -103919
# INFO:lda:<1210> log likelihood: -104126
# INFO:lda:<1220> log likelihood: -104883
# INFO:lda:<1230> log likelihood: -104559
# INFO:lda:<1240> log likelihood: -104593
# INFO:lda:<1250> log likelihood: -104809
# INFO:lda:<1260> log likelihood: -104618
# INFO:lda:<1270> log likelihood: -104479
# INFO:lda:<1280> log likelihood: -104583
# INFO:lda:<1290> log likelihood: -104826
# INFO:lda:<1300> log likelihood: -104836
# INFO:lda:<1310> log likelihood: -104965
# INFO:lda:<1320> log likelihood: -104750
# INFO:lda:<1330> log likelihood: -105405
# INFO:lda:<1340> log likelihood: -105086
# INFO:lda:<1350> log likelihood: -104577
# INFO:lda:<1360> log likelihood: -104547
# INFO:lda:<1370> log likelihood: -104920
# INFO:lda:<1380> log likelihood: -104433
# INFO:lda:<1390> log likelihood: -104491
# INFO:lda:<1400> log likelihood: -104848
# INFO:lda:<1410> log likelihood: -104503
# INFO:lda:<1420> log likelihood: -104601
# INFO:lda:<1430> log likelihood: -104751
# INFO:lda:<1440> log likelihood: -104819
# INFO:lda:<1450> log likelihood: -105037
# INFO:lda:<1460> log likelihood: -104973
# INFO:lda:<1470> log likelihood: -104743
# INFO:lda:<1480> log likelihood: -104289
# INFO:lda:<1490> log likelihood: -104284
# INFO:lda:<1499> log likelihood: -104198
# 0.19066436290740968 minutes

# %%
vocab = vectorizer.get_feature_names()
topic_names = ['Topic %d'%k for k in range(1, n_topics + 1)]

topic_word_distributions = pd.DataFrame(topic_model.components_, columns=vocab, index=topic_names)

document_topic_distributions = pd.DataFrame(document_topic_distributions, columns=topic_names, index=doc_ids)

# %%
document_topic_distributions.to_csv('data/document_topic_distributions_'+str(n_topics)+'topics.csv')
topic_word_distributions.to_csv('data/topic_word_distributions_'+str(n_topics)+'topics.csv')

# %%
document_topic_distributions.head()
# Out:
#    Topic 1  Topic 2  Topic 3  Topic 4  Topic 5  Topic 6  Topic 7  Topic 8  \
# 0     0.10     0.10     0.10     0.10     0.10     0.10     0.10     0.10
# 1     0.05     0.55     0.05     0.05     0.05     0.05     0.05     0.05
# 2     0.10     0.10     0.10     0.10     0.10     0.10     0.10     0.10
# 3     0.55     0.05     0.05     0.05     0.05     0.05     0.05     0.05
# 4     0.10     0.10     0.10     0.10     0.10     0.10     0.10     0.10
#
#    Topic 9  Topic 10
# 0     0.10      0.10
# 1     0.05      0.05
# 2     0.10      0.10
# 3     0.05      0.05
# 4     0.10      0.10

# %%
topic_word_distributions.head()
# Out:
#               110  altersarmut    arbeit  arbeitslosigkeit  arbeitsmarkt  \
# Topic 1  0.000004     0.039177  0.000004          0.152865      0.038326
# Topic 2  0.000004     0.000004  0.000004          0.285033      0.000004
# Topic 3  0.000004     0.000004  0.040888          0.009667      0.000004
# Topic 4  0.000004     0.044068  0.000004          0.000004      0.007705
# Topic 5  0.000004     0.022665  0.000004          0.000004      0.000004
#
#          arbeitsplätze       arm     armut  asylanten  asylpolitik  \
# Topic 1       0.000004  0.000004  0.000004   0.063873     0.000004
# Topic 2       0.019032  0.000004  0.000400   0.000004     0.000004
# Topic 3       0.000004  0.000004  0.053524   0.000004     0.000004
# Topic 4       0.000004  0.000004  0.000004   0.000004     0.142889
# Topic 5       0.000004  0.000004  0.010758   0.000004     0.000004
#
#             ...       sicherheit   soziale  staatsverschuldung   steuern  \
# Topic 1     ...         0.000004  0.000004            0.000004  0.037900
# Topic 2     ...         0.000004  0.000004            0.072153  0.133203
# Topic 3     ...         0.000004  0.000004            0.000004  0.025277
# Topic 4     ...         0.159145  0.000004            0.000004  0.000004
# Topic 5     ...         0.005381  0.512381            0.000004  0.000004
#
#          ungerechtigkeit  verschuldung      volk  wirtschaft  \
# Topic 1         0.000004      0.002133  0.000004    0.026829
# Topic 2         0.000004      0.089992  0.000004    0.000004
# Topic 3         0.000004      0.000004  0.000004    0.000004
# Topic 4         0.000004      0.000004  0.000004    0.000004
# Topic 5         0.159402      0.000004  0.000004    0.000004
#
#          wirtschaftskrise  zuwanderung
# Topic 1          0.000004     0.000004
# Topic 2          0.065414     0.000004
# Topic 3          0.000004     0.003720
# Topic 4          0.000004     0.124066
# Topic 5          0.000004     0.000004
#
# [5 rows x 55 columns]

# %%
topic_word_distributions.loc['Topic 3'].sort_values(ascending=False).head(15)
# Out:
# geld           0.165026
# deutschland    0.128974
# politiker      0.078798
# euro           0.078055
# probleme       0.063931
# ausländer      0.060214
# menschen       0.056498
# armut          0.053524
# schulden       0.052409
# regierung      0.052409
# arbeit         0.040888
# bevölkerung    0.033826
# problem        0.030481
# steuern        0.025277
# bürger         0.023047
# Name: Topic 3, dtype: float64
